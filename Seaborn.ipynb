# %% [markdown]
# **Import Seaborn**

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Dataset**
#
# Seaborn has in-build dataset. These dataset can be initially used for learning and practising purpose

# %%
data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **Distribution plots**
#
# The plots which allows us to visualize the dataset are,
# *  distplot()
# *  jointplot()
# * pairplot()
# * rugplot()
# *  kdeplot()

# %% [markdown]
# **Distplot()**
#
# Distplot() shows distribution has ***univariant*** set of observation

# %%
sns.distplot(data['total_bill'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['total_bill'],kde=False,bins=30)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Jointplot()**
#
# jointplot() allows you to basically match up two distplots for ***bivariate data***.
# They display 'scatter','reg','resid','kde','hex' kind of plots.

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='resid')

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='hex')

# %% [markdown]
# **Pairplot()**
#
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue='sex')

# %%
sns.pairplot(data,hue='sex',palette='coolwarm')

# %% [markdown]
# **Rugplot()**
#
# They just draw a dash mark for every point on a univariate distribution. They are the building block of a KDE plot

# %%
sns.rugplot(data['total_bill'])

# %% [markdown]
# **Kdeplot()**
#
# kdeplots are ***Kernel Density Estimation*** plots. These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value

# %%
sns.kdeplot(data['total_bill'])

# %%
sns.rugplot(data['total_bill'])
sns.kdeplot(data['total_bill'])

# %%
sns.rugplot(data['tip'])
sns.kdeplot(data['tip'])

# %% [markdown]
# **Categorical Plots**
#
# The following are some categorical plots,
# * Catplot()
# * boxplot()
# * violinplot()
# * stripplot()
# * swarmplot()
# * barplot()
# * countplot()

# %% [markdown]
# **Barplot()**
#
# Barplot() allows to aggregate the categorial data based on some function.
# By deafult, any series in Y axis is **mean**.
# To change , ***estimator*** can be used

# %%
sns.barplot(x='sex', y='total_bill',data=data)

# %%
import numpy as np
sns.barplot(x='sex',y='total_bill',data=data,estimator=np.std)

# %% [markdown]
# **Countplot()**
#
# This is same as barplot() except the estimator is explicitly counting the number of occurrences.
# By default, y axis is count in counterplot()

# %%
sns.countplot(x='sex',data=data)

# %% [markdown]
# **Boxplot()**
#
# This plot shows the distribution of quantitative data in way that facilitates comparision between variables or across levels of a categorical variable.

# %%
sns.boxplot(x='day',y='total_bill',data=data,palette='rainbow')

# %%
sns.boxplot(x='sex',y='tip',data=data,palette='rainbow')

# %%
sns.boxplot(data=data,orient='h') # orient - to represent the data in horizontal

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=data,palette='coolwarm')

# %% [markdown]
# **Violinplot()**

# %%
sns.violinplot(x='day',y='total_bill',data=data)

# %%
sns.violinplot(x='day',y='tip',hue='smoker',data=data)

# %%
sns.violinplot(x='day',y='tip',hue='smoker',data=data,split=True)

# %% [markdown]
# **Stripplot()**
#
# It is similar to scatter which is being used for categorical data.

# %%
sns.stripplot(x='day',y='total_bill',data=data) #Output is in scattered form

# %%
sns.stripplot(x='day',y='total_bill',data=data,jitter=False)

# %%
sns.stripplot(x='day',y='total_bill',data=data,jitter=False,hue='sex')

# %%
sns.stripplot(x='day',y='total_bill',data=data,jitter=False,hue='sex',split=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Swarmplot()**
#
# This plot is similar to violinplot.Difference between stripplot and swarmplot is that swarmplot scatters the points and shows clear marking for the result where it is difficult to find in stripplot.

# %%
sns.swarmplot(x='sex',y='tip',data=data)

# %%
sns.swarmplot(x='day',y='total_bill',data=data)

# %%
sns.swarmplot(x='day',y='total_bill',data=data,hue='sex')

# %%
sns.swarmplot(x='day',y='total_bill',data=data,hue='sex',dodge=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Combining two Categorical plots**

# %%
sns.violinplot(x='day',y='total_bill',data=data)
sns.swarmplot(x='day',y='total_bill',color='black',data=data)

# %%
sns.violinplot(x='total_bill',y='day',data=data)
sns.swarmplot(x='total_bill',y='day',color='black',data=data,size=3) #size=3 to make size of each point small

# %% [markdown]
# **Catplot()**
#
# It is general form of categorial plots.
# kind - bar,box,violin,strip etc,.

# %%
sns.catplot(x='sex',y='tip',kind='bar',data=data)

# %% [markdown]
# **Matrix plots()**
#
# Matrix plots allow you to plot data as ***color-encoded matrices***.

# %%
ds = sns.load_dataset('flights')

# %%
ds.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data.corr())

# %% [markdown]
# To display the vaules inside the heatmap and to change colour of heatmap

# %%
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')

# %%
sns.heatmap(data.corr(),annot=True,cmap='rainbow')

# %%
pt = ds.pivot_table(values='passengers',index='month',columns='year')
pt
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# Another sample pivot table

# %%
ds.pivot_table(values='passengers',index='year',columns='month')
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(pt)

# %%
sns.heatmap(pt,linecolor='white',linewidth=1)

# %%
sns.heatmap(pt,linecolor='white',linewidth=1,cmap='magma')

# %% [markdown]
# **Grid**
#
# Grids are general types of plots that allow you to map plot types to rows and columns of a grid, this helps you create similar plots separated by features.

# %%
import matplotlib.pyplot as plt

# %%
dst = sns.load_dataset('iris')

# %%
dst
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # To display unique species

# %%
dst['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# **PairGrid**
#
# Pairgrid is a subplot grid for plotting pairwise relationships in a dataset.

# %%
sns.PairGrid(dst)   #This is create just the grid

# %% [markdown]
# ## Same kind of plot for all the grids

# %%
g = sns.PairGrid(dst) 
g.map(plt.scatter)

# %% [markdown]
# # Customizing kind of plots

# %%
g = sns.PairGrid(dst)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# **Pairplot()**
#
# pairplot is a simpler version of PairGrid (you'll use quite often).Incase of no customization , we can choose pairplot. Diagonals of pairplot is by default ***histogram*** and others are ***scatter*** plot.

# %%
sns.pairplot(dst)

# %% [markdown]
# # Classification between species

# %%
sns.pairplot(dst,hue='species')

# %% [markdown]
# **Facet grid**
#
# FacetGrid is the general way to create grids of plots based off of a feature:

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
f = sns.FacetGrid(data,col='time',row='smoker')

# %%
f = sns.FacetGrid(data,col='time',row='smoker')
f = f.map(plt.hist,'total_bill')

# %%
f = sns.FacetGrid(data,col='time',row='smoker',hue='sex')
f.map(plt.scatter,'total_bill','tip').add_legend()

# %% [markdown]
# **JointGrid**
#
# JointGrid is the general version for jointplot() type grids

# %%
j = sns.JointGrid(data=data,x='total_bill',y='tip')

# %%
j = sns.JointGrid(data=data,x='total_bill',y='tip')
j.plot(sns.regplot,plt.hist)

# %% [markdown]
# **Regression plots**
#
# ***lmplot*** allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(x='total_bill',y='tip',data=data)

# %%
sns.lmplot(x='total_bill',y='tip',data=data,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=data,hue='sex',palette='rainbow')

# %% [markdown]
# **Working with Markers**
#
# lmplot kwargs get passed through to regplot which is a more general form of lmplot(). regplot has a scatter_kws parameter that gets passed to plt.scatter. So you want to set the s parameter in that dictionary, which corresponds (a bit confusingly) to the squared markersize. In other words you end up passing a dictionary with the base matplotlib arguments, in this case, s for size of a scatter plot. In general, you probably won't remember this off the top of your head, but instead reference the documentation.

# %%
sns.lmplot(x='total_bill',y='tip',data=data,hue='sex',palette='coolwarm',markers=['o','v'],scatter_kws={'s':100})

# %% [markdown]
# # Using Grid

# %%
sns.lmplot(x='total_bill',y='tip',col='time',data=data)

# %%
sns.lmplot(x='total_bill',y='tip',col='time',row='sex',hue='sex',data=data)

# %%
sns.lmplot(x='total_bill',y='tip',col='day',hue='sex',data=data)

# %% [markdown]
# **Aspect and Size**
#
#
# Seaborn figures can have their size and aspect ratio adjusted with the size and aspect parameters:

# %%
sns.lmplot(x='total_bill',y='tip',col='day',hue='sex',data=data,aspect=0.8,size=8)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
